# %% [markdown]
# # Relatório de Análise IV

# %% [markdown]
# ## Seleções de Frequências

# %%
import pandas as pd

# %%
dados = pd.read_csv('csvfiles/aluguel_residencial.csv', sep = ';')

# %%
dados.head(15)
# Out:
#                   Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0            Quitinete           Copacabana        1      0       0    40
# 1                 Casa      Jardim Botânico        2      0       1   100
# 2          Apartamento               Centro        1      0       0    15
# 3          Apartamento         Higienópolis        1      0       0    48
# 4          Apartamento         Vista Alegre        3      1       0    70
# 5          Apartamento             Cachambi        2      0       0    50
# 6   Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 7   Casa de Condomínio                Ramos        2      2       0    65
# 8          Apartamento               Centro        1      0       0    36
# 9          Apartamento               Grajaú        2      1       0    70
# 10         Apartamento  Lins de Vasconcelos        3      1       1    90
# 11         Apartamento           Copacabana        1      0       1    40
# ...

# %%
# Selecione somente os imóveis classificados com tipo 'Apartamento'.

# %%
selecao_1 = dados['Tipo'] == 'Apartamento'
selecao_apartamento = dados[selecao_1]

# %%
selecao_apartamento
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# 5      Apartamento              Cachambi        2      0       0    50
# 8      Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 22573  Apartamento        Vila Valqueire        2      0       0    52
# 22575  Apartamento                 Méier        2      0       0    70
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 2       800.0       390.0  20.0
# 3       800.0       230.0   NaN
# ...

# %%
frequencia_apartamento = dados[selecao_1].shape[0]

# %%
frequencia_apartamento
# Out:
# 19532

# %%
# Selecione os imóveis classificados com tipos 'Casa', 'Casa de Condomínio' e 'Casa de Vila'.

# %%
selecao_2 = (dados['Tipo'] == 'Casa') | (dados['Tipo'] == 'Casa de Condomínio') | (dados['Tipo'] == 'Casa de Vila')

# %%
selecao_casas = dados[selecao_2]

# %%
selecao_casas
# Out:
#                      Tipo                   Bairro  Quartos  Vagas  Suites  \
# 1                    Casa          Jardim Botânico        2      0       1
# 6      Casa de Condomínio          Barra da Tijuca        5      4       5
# 7      Casa de Condomínio                    Ramos        2      2       0
# 14     Casa de Condomínio                  Taquara        3      1       1
# 18     Casa de Condomínio          Barra da Tijuca        4      3       2
# ...                   ...                      ...      ...    ...     ...
# 22545  Casa de Condomínio  Freguesia (Jacarepaguá)        3      3       1
# 22547                Casa            Bento Ribeiro        2      1       0
# 22555  Casa de Condomínio          Barra da Tijuca        3      5       3
# 22558                Casa                   Centro        5      0       1
# 22574  Casa de Condomínio          Barra da Tijuca        5      3       4
#
#        Area    Valor  Condominio    IPTU
# ...

# %%
frequencia_casa = dados[selecao_2].shape[0]

# %%
frequencia_casa
# Out:
# 2212

# %%
# Selecione os imóveis com área entre 60 e 100 metros quadrados, incluindo os limites.

# %%
selecao_3 = (dados['Area'] >=60) & (dados['Area']<=100)

# %%
m_quadrados_60a100 = dados[selecao_3]

# %%
frequenciam_quadrados_60a100 = dados[selecao_3].shape[0]

# %%
frequenciam_quadrados_60a100
# Out:
# 8719

# %%
# Selecione os imóveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00.

# %%
selecao_4 = (dados['Quartos'] >= 4) & (dados['Valor'] < 2000)

# %%
imoveis_selecao_4 = dados[selecao_4]

# %%
frequencia_imoveis_selecao_4 = dados[selecao_4].shape[0]

# %%
frequencia_imoveis_selecao_4
# Out:
# 41
